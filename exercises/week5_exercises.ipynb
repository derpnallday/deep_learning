# %% [markdown]
# > **DO NOT EDIT IF INSIDE annadl_f19 folder**

# %% [markdown]
# # Week 5: Recurrent neural networks
#
# Text, speech, weather, sensor output and video are but a few examples of the many types of data that is inherently sequential. So how does one predict the next word in a sentence, future temperatures or missing video frames? Using **recurrent neural networks** (RNNs)!

# %%
# %matplotlib inline
# %load_ext tensorboard
import numpy as np
import random
import sys
import io
from bs4 import BeautifulSoup
from keras.callbacks import LambdaCallback
from keras.models import Sequential
from keras.layers import Dense, LSTM
from keras.optimizers import RMSprop
import requests
import datetime
import keras
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Exercises

# %% [markdown]
# #### Modeling text

# %% [markdown]
# Text prediction is a good place to start when learning about RNNs, because most of us humans have a pretty well
# optimized inner model for text prediction ourselves. We can, therefore, easily assess the performance of a neural
# network in executing this task.
#
# Below is some code that loads the screenplay for Tarantino's 1994 film 'Pulp Fiction'. I recommend reading through the
# first 20 lines or so to get a feeling for the language and style used (and enjoy probably the best written screenplay
# in the history of film).

# %%
response = requests.get("http://www.dailyscript.com/scripts/pulp_fiction.html")
text = BeautifulSoup(response.content, "html.parser").getText()
print(text[:2000])
# Out:
# "PULP FICTION" -- by Quentin Tarantino & Roger Avary
#
#
#                                       "PULP FICTION"
#
#                                             By
#
#                              Quentin Tarantino & Roger Avary
#
#
#
#                PULP [pulp] n.
#
#                1. A soft, moist, shapeless mass or matter.
#
#                2. A magazine or book containing lurid subject matter and
#                being characteristically printed on rough, unfinished paper.
#
#                American Heritage Dictionary: New College Edition
#
#                INT. COFFEE SHOP – MORNING
#
#                A normal Denny's, Spires-like coffee shop in Los Angeles.
#                It's about 9:00 in the morning. While the place isn't jammed,
#                there's a healthy number of people drinking coffee, munching
#                on bacon and eating eggs.
#
#                Two of these people are a YOUNG MAN and a YOUNG WOMAN. The
#                Young Man has a slight working-class English accent and,
#                like his fellow countryman, smokes cigarettes like they're
#                going out of style.
#
#                It is impossible to tell where the Young Woman is from or
#                how old she is; everything she does contradicts something
#                she did. The boy and girl sit in a booth. Their dialogue is
#                to be said in a rapid pace "HIS GIRL FRIDAY" fashion.
#
#                                      YOUNG MAN
#                          No, forget it, it's too risky. I'm
#                          through doin' that shit.
#
#                                      YOUNG WOMAN
#                          You always say that, the same thing
#                          every time: never again, I'm through,
#                          too dangerous.
#
#                                      YOUNG MAN
#                          I know that's what I always say. I'm
#                          always right too, but –

# %% [markdown]
# > **Ex. 5.1.1:** What is the most used symbol in this screenplay and what accuracy would a model constantly predicting this symbol obtain? In other words, what is the "baseline accuracy"?

# %% [markdown]
# I've adapted some code for text generation from [this Keras example](https://keras.io/examples/lstm_text_generation/).
# I've inserted some questions in the code (look for `Q:`) for you to answer in the exercise below.

# %%
# Q1: What is the purpose of this block? When is `char_indices` used? What about `indices_char`?
# makes a list of all the characters then makes to dict pairs where one dict is a character to index and the
# other is index to character. This is to help the algorithm see the word order and commonality of certain 
# characters
chars = sorted(list(set(text)))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))

# Q2: What is the purpose of this block? What does the `seqlen` and `step` parameters do?
# seqlen is the length of the sequence of text grabed at each iteration, the step parameter skips over to the 
# next seqlen of characters. Each seqlen of text is evaluated as a sentence and appended to sentences
seqlen = 40
step = seqlen
sentences = []
for i in range(0, len(text) - seqlen - 1, step):
    sentences.append(text[i: i + seqlen + 1])

# Q3: What about this block? What is `x` and what is `y`? Why do they have this dimensionality?
# x is a character and y is the character after x. They are of the dimensions len(sentences) and seqlen
# because we input all the sentences into the matrix and the sentences are seqlen
x = np.zeros((len(sentences), seqlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), seqlen, len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    # Q3a: What happens in this loop?
    # sets x as a character and y as the character after it
    for t, (char_in, char_out) in enumerate(zip(sentence[:-1], sentence[1:])):
        x[i, t, char_indices[char_in]] = 1
        y[i, t, char_indices[char_out]] = 1


# Q4: Here we build the model. What does the `return_sequences` argument do? Why the dense layer at the end?
# the return sequences tells whether to return the last output in the output sequence, or the full sequence.
# the final dense layer maps to each single unique character found in the input sequence
model = Sequential()
model.add(LSTM(128, input_shape=(seqlen, len(chars)), return_sequences=True))
model.add(Dense(len(chars), activation='softmax'))

model.compile(
    loss='categorical_crossentropy',
    optimizer=RMSprop(learning_rate=0.01),
    metrics=['categorical_crossentropy', 'accuracy']
)

def sample(preds, temperature=1.0):
    """Helper function to sample an index from a probability array."""
    preds = np.asarray(preds).astype('float64')
    preds = np.exp(np.log(preds) / temperature)  # softmax
    preds = preds / np.sum(preds)                #
    probas = np.random.multinomial(1, preds, 1)  # sample index
    return np.argmax(probas)                     #


def on_epoch_end(epoch, _):
    """Function invoked at end of each epoch. Prints generated text."""
    print()
    print('----- Generating text after Epoch: %d' % epoch)

    start_index = random.randint(0, len(text) - seqlen - 1)
    
    # Q5: What does diversity do?
    for diversity in [0.2, 0.5, 1.0]:
        print('----- diversity:', diversity)

        generated = ''
        sentence = text[start_index: start_index + seqlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x_pred = np.zeros((1, seqlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.
            
            # What is the dimensionality of `preds`? Why do we input `preds[0, -1]` to the `sample` function?
            preds = model.predict(x_pred, verbose=0)
            next_index = sample(preds[0, -1], diversity)
            next_char = indices_char[next_index]

            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()

print_callback = LambdaCallback(on_epoch_end=on_epoch_end)



log_dir="./logs/wk5_1/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = keras.callbacks.TensorBoard(log_dir=log_dir)

# %%
model.fit(x, y,
          batch_size=128,
          epochs=50,
          callbacks=[print_callback, tensorboard_callback])
# Out:
# Epoch 1/50
# 7614/7614 [==============================] - 8s 1ms/step - loss: 2.2236 - categorical_crossentropy: 2.2236 - accuracy: 0.5426
#
# ----- Generating text after Epoch: 0
# ----- diversity: 0.2
# ----- Generating with seed: "ee.
#
#                The Young Man goes"
# ee.
#
#                The Young Man goes
# ----- diversity: 0.5
# ----- Generating with seed: "ee.
#
#                The Young Man goes"
# ee.
#
#                The Young Man goes roe  o
# ----- diversity: 1.0
# ----- Generating with seed: "ee.
#
#                The Young Man goes"
# ee.
#
#                The Young Man goesmth.
#         h                                 hUs w          T        odu                        makiimo s onrt   thk detha wrtte dhe.
#
#      I            J                        m             T                         o  c
#         W                      ba oMswvw,'rom'aace u                                               ve        nsat soODa
#
#          W n   o
# Epoch 2/50
# 7614/7614 [==============================] - 6s 817us/step - loss: 1.4267 - categorical_crossentropy: 1.4267 - accuracy: 0.6332
#
# ----- Generating text after Epoch: 1
# ----- diversity: 0.2
# ----- Generating with seed: "   FABIENNE
#                          I "
#    FABIENNE
#                          I dout the the the the the cont the the the the the the the the the the the the the the the the the the the the
#
# ----- diversity: 0.5
# ----- Generating with seed: "   FABIENNE
#                          I "
#    FABIENNE
#                          I CHENG
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "   FABIENNE
#                          I "
#    FABIENNE
#                          I mang mver thann ay.
#
#                                           cell!
#
#                                               BUTCH
#            BItVck ly bress fonny Buck avint, gimt, anoy f thnighps, youno hiinp.ngotetetsennins indis
#                               HanchitH
#
#              INCEENS
#      Whalk thes.
#
#              Wartast ME
#            SUAGHNUUS INGANBON
#                   ounvisyt?
#
# Epoch 3/50
# 7614/7614 [==============================] - 6s 776us/step - loss: 1.2158 - categorical_crossentropy: 1.2158 - accuracy: 0.6774 0s - loss: 1.2151 - categorical_crossentropy: 1.2151 - accuracy: 0.677
#
# ----- Generating text after Epoch: 2
# ----- diversity: 0.2
# ----- Generating with seed: "                     ...warm. Warmer. Di"
#                      ...warm. Warmer. Ding in the sing
#
# ----- diversity: 0.5
# ----- Generating with seed: "                     ...warm. Warmer. Di"
#                      ...warm. Warmer. Dincen toust this
#
# ----- diversity: 1.0
# ----- Generating with seed: "                     ...warm. Warmer. Di"
#                      ...warm. Warmer. Dilkt is:s.chis, shonnt
#           Whink silkss Piint ass, Danne wannkes. WOep out sind inwing
#       amn's sing hiad
#           Erivard runnn a hen told end of owfbly.
#
#                             diskes. Lell ancs on hto Pnamy,
#                   sutt pagisbaiguckon' metsallisk ring, thom, with taces npensind.
#
#                           TARENG TH
#                   fidminf and,
#
# Epoch 4/50
# 7614/7614 [==============================] - 51s 7ms/step - loss: 1.1123 - categorical_crossentropy: 1.1123 - accuracy: 0.7019TA: 4:52 - loss: 1.1377 - categorical_crossentropy: 1.1377 - accuracy: - ETA: 2:16
#
# ----- Generating text after Epoch: 3
# ----- diversity: 0.2
# ----- Generating with seed: "               You don't think he overre"
#                You don't think he overrentares of
#
# ----- diversity: 0.5
# ----- Generating with seed: "               You don't think he overre"
#                You don't think he overrer.
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "               You don't think he overre"
#                You don't think he overreaps of Mavice in mess.
#
#                               Bundy.
#
#                                       JULES
#                       Vince. Jemy jorns inttind. Vincent, of afpeau
#      Vey a Nonna a asceut, bakedaw prist-to nigless as his bow he bid
#                      BITOH
#                                ingersce,!
#
#                of Hagey Rucces.
#
#                      Hhes limenin' by t
# Epoch 5/50
# 7614/7614 [==============================] - 6s 783us/step - loss: 1.0463 - categorical_crossentropy: 1.0463 - accuracy: 0.7186
#
# ----- Generating text after Epoch: 4
# ----- diversity: 0.2
# ----- Generating with seed: "Brett)
#                          Now I'm"
# Brett)
#                          Now I'm not a towered here he peat
#
# ----- diversity: 0.5
# ----- Generating with seed: "Brett)
#                          Now I'm"
# Brett)
#                          Now I'm got of the copped and his hand.
#                                                                                                                                                                                               BUTCH
#
# ----- diversity: 1.0
# ----- Generating with seed: "Brett)
#                          Now I'm"
# Brett)
#                          Now I'me wa coneme.
#
#                                   The mannempliced of fe't and
#                    Vanceniod kace.
#
#                                       creap-atha callan, suref)"Breeve
#                                 JULES
#                                   9usules out!
#
#                           Butch kingy and I dnough stantersheemore.
#
#                                     Dood, to tex
# Epoch 6/50
# 7614/7614 [==============================] - 6s 789us/step - loss: 0.9963 - categorical_crossentropy: 0.9963 - accuracy: 0.7309
#
# ----- Generating text after Epoch: 5
# ----- diversity: 0.2
# ----- Generating with seed: "               forgittin' are over, and "
#                forgittin' are over, and the shot
#
# ----- diversity: 0.5
# ----- Generating with seed: "               forgittin' are over, and "
#                forgittin' are over, and where.
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "               forgittin' are over, and "
#                forgittin' are over, and thewe shorf. ince the jets the
#                               angliqus of hem minamped)
#                              getthing the blandlep?
#
#                           Openine the WaPS PAnes: betcinsing this gets Cope stomm,
#                       THE DHOV          Nive looks a trorker to howe comoutes. Shere
#                      wirl Nowt.
#
#                              JULES
#
# Epoch 7/50
# 7614/7614 [==============================] - 6s 776us/step - loss: 0.9558 - categorical_crossentropy: 0.9558 - accuracy: 0.7407
#
# ----- Generating text after Epoch: 6
# ----- diversity: 0.2
# ----- Generating with seed: "ame is Fabby!
#
#                        "
# ame is Fabby!
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "ame is Fabby!
#
#                        "
# ame is Fabby!
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "ame is Fabby!
#
#                        "
# ame is Fabby!
#
#                                       Srumbory?
#
#                                               gonna I air, that a foor collla
#
#                               Butch SIMPES quchin' mothervie...
#
#                                                         YOUNG WOM
#
#               Wanna eveanin' becog.
#
#                                                WHING BUTCH Butch up cruped lior.  (s.medonister
#
#
# Epoch 8/50
# 7614/7614 [==============================] - 6s 836us/step - loss: 0.9211 - categorical_crossentropy: 0.9211 - accuracy: 0.7483 3s - loss: 0.9298 - categorical_crossent
#
# ----- Generating text after Epoch: 7
# ----- diversity: 0.2
# ----- Generating with seed: "portscasters continue their coverage.
# "
# portscasters continue their coverage.
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "portscasters continue their coverage.
# "
# portscasters continue their coverage.
#
#                                                                   LANCE
#
# ----- diversity: 1.0
# ----- Generating with seed: "portscasters continue their coverage.
# "
# portscasters continue their coverage.
#
#                        VINCETT
#                                   Vincen you seenellians, I'm a gattle.
#
#                                            that allevin' basir)
#                                   No ap it, outs)
#
#                       The Doqueyger manies.
#
#                                         FABIENNE
#                                Okay?
#
#
# Epoch 9/50
# 7614/7614 [==============================] - 6s 761us/step - loss: 0.8907 - categorical_crossentropy: 0.8907 - accuracy: 0.7557
#
# ----- Generating text after Epoch: 8
# ----- diversity: 0.2
# ----- Generating with seed: "IMMIE & THE WOLF"
#
#                TITL"
# IMMIE & THE WOLF"
#
#                TITLE CARELISELDING ROOM – NIGHT
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "IMMIE & THE WOLF"
#
#                TITL"
# IMMIE & THE WOLF"
#
#                TITLE CARDITMERS to the with the box the bull fast
#                                                                                                                                                                                                                            JULES
#
# ----- diversity: 1.0
# ----- Generating with seed: "IMMIE & THE WOLF"
#
#                TITL"
# IMMIE & THE WOLF"
#
#                TITLE CARDIT ROOM – DARNICK
#
#                The TRERINGLDIY, to her points a porber houge sall go to. Maynard
#                              you doing room.
#
#                          Butch walks seom. The big'r amart boom ding look.
#                          As be tob do, I'm gonna be your smord.
#
#                                         hord with just in"  Jiam and Madine Vincent no bedry
#
# Epoch 10/50
# 7614/7614 [==============================] - 6s 791us/step - loss: 0.8670 - categorical_crossentropy: 0.8670 - accuracy: 0.7610 4s - loss: 0.8712 - categori
#
# ----- Generating text after Epoch: 9
# ----- diversity: 0.2
# ----- Generating with seed: "
#                          needle. Five"
#                          needle. Five out a parting a table a pot the
#
# ----- diversity: 0.5
# ----- Generating with seed: "
#                          needle. Five"
#
#                          needle. Fiven and way ready and say
#                          The warked Marsellus out a fight out of the boot
#
# ----- diversity: 1.0
# ----- Generating with seed: "
#                          needle. Five"
#
#                          needle. Five you say simes her his p.ond
#                          peesn my caufies in morbs prust you live
#                              If your golnitiss alleory So Jules, the meses
#                              What's brother? Now thit the treaks her Jimmie genks andy to Jules and Butch CLoncaule, then pets on roal goes a
#                                                 DAYNA
#
#
# Epoch 11/50
# 7614/7614 [==============================] - 6s 808us/step - loss: 0.8454 - categorical_crossentropy: 0.8454 - accuracy: 0.7655
#
# ----- Generating text after Epoch: 10
# ----- diversity: 0.2
# ----- Generating with seed: "            JULES
#                      "
#             JULES
#
# ----- diversity: 0.5
# ----- Generating with seed: "            JULES
#                      "
#             JULES
#                                                                   VINCENT
#                                                                                                                                                                                                                                                                 JULES
#
# ----- diversity: 1.0
# ----- Generating with seed: "            JULES
#                      "
#             JULES
#                                                  VINCENT
#                          Ius a flooles anya kand.
#
#                     Don't bull be not you are in Marsellus.
#                          I want bau, never?
#                          The fuce, want out, then can in it.
#            He houves out, me als I'mbel man our peach
#                          out when you pateal after go, and mey.
#
# Epoch 12/50
# 7614/7614 [==============================] - 6s 771us/step - loss: 0.8274 - categorical_crossentropy: 0.8274 - accuracy: 0.7693
#
# ----- Generating text after Epoch: 11
# ----- diversity: 0.2
# ----- Generating with seed: "                  VINCENT
#              "
#                   VINCENT
#                          I don't be not the counter the shot.
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "                  VINCENT
#              "
#                   VINCENT
#                          That was the door. What the repletters to helpone
#                          be a big go for her hear the door.
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "                  VINCENT
#              "
#                   VINCENT
#                                    back doerss Rinate with the bryuns in have the rolltay what I
#                          in froot on thepere. It's one, I'll wafth
#                leaves. Don't get somens.
#
#                Jules, sees to gottin' ther kill, I say. Don't. He
#                          have quart of him.
#
#                The hippee. I just hes the bry lays with a
#                          A
# Epoch 13/50
# 7614/7614 [==============================] - 6s 772us/step - loss: 0.8105 - categorical_crossentropy: 0.8105 - accuracy: 0.7743
#
# ----- Generating text after Epoch: 12
# ----- diversity: 0.2
# ----- Generating with seed: "e player. When the MUSIC starts, he
#   "
# e player. When the MUSIC starts, he
#
# ----- diversity: 0.5
# ----- Generating with seed: "e player. When the MUSIC starts, he
#   "
# e player. When the MUSIC starts, he
#                          They man freak and stands and the buyble do in the apartment to
#                          with a counters to his hand on the Marsellus in the are who eyes
#                          the budny closed, but they got a stay on a bulless on
#                                                                     JULES
#                          Vincent a counter and the morners the
# ----- diversity: 1.0
# ----- Generating with seed: "e player. When the MUSIC starts, he
#   "
# e player. When the MUSIC starts, he
#                          bathroom on ence friken a bitch shots the
#                          what I like numpering, old ya hear
#                          beensheve
#                          room?
#
#                Vincent the herbe in the door of him, he dees never and gonna bully to you.
#
#                                        it wanna been carf.
#
#
# Epoch 14/50
# 7614/7614 [==============================] - 7s 879us/step - loss: 0.7964 - categorical_crossentropy: 0.7964 - accuracy: 0.7775
#
# ----- Generating text after Epoch: 13
# ----- diversity: 0.2
# ----- Generating with seed: "him, eyes and blade now locked on
#     "
# him, eyes and blade now locked on
#                          the shot. The table storting the fuckin'
#                          the shot. I say a metallies. And
#                          the shot.
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "him, eyes and blade now locked on
#     "
# him, eyes and blade now locked on
#                          train on the ond possed in the
#                          thinkin' of the shot.
#
#                                              JULES
#                          What the styreponies.
#
#                                                                          LANCE
#                          I don't think you the somethin'
#                          the shot. And I was not a fitt
# ----- diversity: 1.0
# ----- Generating with seed: "him, eyes and blade now locked on
#     "
# him, eyes and blade now locked on
#                coll "Do us?
#                                           VINCENT
#                          Larks if a copbyess.
#
#                                              BRETT
#                          Vince, kitchag. He told his way and
#                          mor eadina to calley a barbaty. CCmp. And the wall of Fabbel Nord onomie, Maynard instadds, Marsellusn to
#                Marsellus
# Epoch 15/50
# 7614/7614 [==============================] - 6s 773us/step - loss: 0.7829 - categorical_crossentropy: 0.7829 - accuracy: 0.7807
#
# ----- Generating text after Epoch: 14
# ----- diversity: 0.2
# ----- Generating with seed: "
#
#                                     "
#
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "
#
#                                     "
#
#
#                                                                                                                                                                                        VINCENT
#                          What the world make make a fight of the our a box the
#                          out the mores the car bleade like the
#                          I don't was a firth shows the slowne?
#
#                When Jimmie is li
# ----- diversity: 1.0
# ----- Generating with seed: "
#
#                                     "
#
#
#                                           VINCENT
#                          I like what is Mia hill... byers in the just what whoway id a were through a cartions, in to the Thar off.
#
#                Welm vough and MOSON, Vincenticalle insty-
#                onep shoraty pirdersion.
#
#                                            VINCENT
#                          When Madonny, or the big bay a twing if
#                sluciew comar.
# Epoch 16/50
# 7614/7614 [==============================] - 6s 774us/step - loss: 0.7712 - categorical_crossentropy: 0.7712 - accuracy: 0.7842
#
# ----- Generating text after Epoch: 15
# ----- diversity: 0.2
# ----- Generating with seed: "pasm)
#                          I didn't"
# pasm)
#                          I didn't can't see shot.
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "pasm)
#                          I didn't"
# pasm)
#                          I didn't say I say you see shit to
#                          in the bathroom.
#
#                                             VINCENT
#                                                                                                                                                                                                          VINCENT
#
# ----- diversity: 1.0
# ----- Generating with seed: "pasm)
#                          I didn't"
# pasm)
#                          I didn't you gone... was is Buh,
#                reess out of the phool. Answer a foney?
#
#                TALDINA GERS agrinfors, bleve be as?
#
#                                         LaVing.
#
#                A Tnay ROVES it, chomens up!
#
#                Talts at that from it.
#
#                                      What five?
#
#                               Vincens's good, I didn't-you.
#
#
# Epoch 17/50
# 7614/7614 [==============================] - 6s 775us/step - loss: 0.7605 - categorical_crossentropy: 0.7605 - accuracy: 0.7865
#
# ----- Generating text after Epoch: 16
# ----- diversity: 0.2
# ----- Generating with seed: "         Marsellus brings up his weapon "
#          Marsellus brings up his weapon and stands the door behind the
#                          shit of the straige the straight that shit
#                          the straige a shower door.
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "         Marsellus brings up his weapon "
#          Marsellus brings up his weapon sits the street and the stard this out and
#                          on the manch was that that is a right
#                          this in the fuck doesn't this ready
#                          the newled of the restaurant. The
#                          don't go barker that fuckin' boys a didn't
#                          comes that who have her the street.
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "         Marsellus brings up his weapon "
#          Marsellus brings up his weapon parkfied in the gonna
#                          on a briezegis MOTELDA
#                                             FABIENNE
#                          What's Maline shitch in her on ar mordeats.  The two bathroom
#                          friend tarks it malking a call all like a
#                               (sticking Barter drencty junning to the
#                          ever My naspns and
# Epoch 18/50
# 7614/7614 [==============================] - 7s 924us/step - loss: 0.7551 - categorical_crossentropy: 0.7551 - accuracy: 0.7898
#
# ----- Generating text after Epoch: 17
# ----- diversity: 0.2
# ----- Generating with seed: "           You ever read the Bible, Bret"
#            You ever read the Bible, Brett.
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "           You ever read the Bible, Bret"
#            You ever read the Bible, Brett.
#
#                                                                                                                                              VINCENT
#                          No the smord on his a five don't problems.
#
#                                                                                                             JULES
#                          I don't walk and you two loth of
# ----- diversity: 1.0
# ----- Generating with seed: "           You ever read the Bible, Bret"
#            You ever read the Bible, Brett, but poops and his starded and a wite,
#                          think big shote the charternimation,
#                rightes?
#
#                                      BUTCH
#                          Noney butcr.
#
#                Then I glewtrawnsolice, quiet, I give
#                          trunk I'm gonna bit with the PEttreAWhing Mircol.
#
#                Jody, and I don't in Mirsings up,
# Epoch 19/50
# 7614/7614 [==============================] - 7s 882us/step - loss: 0.7424 - categorical_crossentropy: 0.7424 - accuracy: 0.7910
#
# ----- Generating text after Epoch: 18
# ----- diversity: 0.2
# ----- Generating with seed: "ncakes?
#
#                              "
# ncakes?
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "ncakes?
#
#                              "
# ncakes?
#                                               JULES
#                          What did you walk the past be a phin
#                          deed a culler a bitch stacts the shake
#                          but you guy the open street. I'm
#                          sincent stopped the shot.
#
#                                                     JULES
#                          What don't you gotta know. They comes
#
# ----- diversity: 1.0
# ----- Generating with seed: "ncakes?
#
#                              "
# ncakes?
#
#                                      VINCENT
#                          She's securaina bat she hagare.
#
#                Vince I sure head, don't arright no
#                          go out off got my all the car as. We
#                    the blooding, in martrot-the-forsterd kneckes through a huss in the
#                Spakes. Reated bach this shit
#                          place, STINNG his stile scarition.
#
#
# Epoch 20/50
# 7614/7614 [==============================] - 7s 876us/step - loss: 0.7338 - categorical_crossentropy: 0.7338 - accuracy: 0.7941
#
# ----- Generating text after Epoch: 19
# ----- diversity: 0.2
# ----- Generating with seed: "me more.
#
#                             "
# me more.
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "me more.
#
#                             "
# me more.
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "me more.
#
#                             "
# me more.
#
#                                                 bitch should at treandon.
#
#                                            He's leanca is my fuckin' door, cheok, bulss
#                of a taWe.
#
#                Everythat here, Warking a bluyiking gooth
#                          danct head)
#                          Door alk ya say.
#
#                                            do it a nambuck?
#
#                Foband you j
# Epoch 21/50
# 7614/7614 [==============================] - 7s 912us/step - loss: 0.7270 - categorical_crossentropy: 0.7270 - accuracy: 0.7955
#
# ----- Generating text after Epoch: 20
# ----- diversity: 0.2
# ----- Generating with seed: "ad: "yes."
#
#                           "
# ad: "yes."
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "ad: "yes."
#
#                           "
# ad: "yes."
#
#                                                                        LANCE
#                          Jules and the table with his face.
#
#                                                      JULES
#                                                                            JULES
#                          What does head as lead that was a start
#                          the start. He like this ass.
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "ad: "yes."
#
#                           "
# ad: "yes."
#
#                                         YOUNG MAN
#                Butch lices of ans coffeching, his jawinnows on his gun he pies alont, you're getty you-onminity her
#                          what you had the lives on his ficep of his hand.
#
#                Mia I nieedoa Flund Vincent eatless – no
#                          Boes as the tericar ams it?
#
#                                             JULES
#
# Epoch 22/50
# 7614/7614 [==============================] - 7s 884us/step - loss: 0.7194 - categorical_crossentropy: 0.7194 - accuracy: 0.7968
#
# ----- Generating text after Epoch: 21
# ----- diversity: 0.2
# ----- Generating with seed: "   talk about drug shit on a cellular
# "
#    talk about drug shit on a cellular
#                          the shot. The big mad front of the bathroom and stands the morning to the car of all this is
#                          be a problem and lets it that a morning
#                          the fuckin' way.
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "   talk about drug shit on a cellular
# "
#    talk about drug shit on a cellular
#                          a long really bull, it's a coffee on the
#                          sticks up and this movie me it. And I don't
#                                                               JULES
#                          I don't mean that bedroom of what what it to
#                          in a bull thinkin' for in the morning. Thin
#
# ----- diversity: 1.0
# ----- Generating with seed: "   talk about drug shit on a cellular
# "
#    talk about drug shit on a cellular
#                          like like there's inside of war
#                                    I was unless talkin' bullarim tells, I needle saye –
#
#                She spides down on the burne xit.
#
#                EXT. JIMMIE res.
#
#                Their back and HADAKE – Marance
#                          them workeve seen her house feenshing this case.
#                                 WhathI
# Epoch 23/50
# 7614/7614 [==============================] - 7s 891us/step - loss: 0.7120 - categorical_crossentropy: 0.7120 - accuracy: 0.7993
#
# ----- Generating text after Epoch: 22
# ----- diversity: 0.2
# ----- Generating with seed: "d
#                          I'm talkin'"
# d
#                          I'm talkin' that they call they pauth.
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "d
#                          I'm talkin'"
# d
#                          I'm talkin' the right, walking out a plack of
#                          the rest the spect. Maynard the boxer the
#                          gun he speak peemshen and starts to
#                          they get the phone, better be need to be the
#                          the right. The two well the rippin'
#                          speck and starts the only starts the
#                          the eye
# ----- diversity: 1.0
# ----- Generating with seed: "d
#                          I'm talkin'"
# d
#                          I'm talkin' rephe.
#
#                The Wolf and know whouly Soay milling man,
#                          get builting. She alint.
#
#                                                THE WOLF
#                          We doesn't met me road and gots at her here, seeps
#                Big Macoters?
#
#                                      VINCENT
#                          Same to be as the car, then goes the n
# Epoch 24/50
# 7614/7614 [==============================] - 7s 882us/step - loss: 0.7069 - categorical_crossentropy: 0.7069 - accuracy: 0.8004
#
# ----- Generating text after Epoch: 23
# ----- diversity: 0.2
# ----- Generating with seed: "                         What so you wan"
#                          What so you want to his hand on the door and the shows the
#                          the shows the street and stand and the
#                          the shows the street and stand and
#                          the shows the shows the street and stand and
#                          the shows the shows the street and play and
#                          the shows the shows the shows the bag for a
#
# ----- diversity: 0.5
# ----- Generating with seed: "                         What so you wan"
#                          What so you want to a foot massage and
#                          the shotgung the street, like a darkness,
#                          on he with his ass a racing coffee and
#                          the door the shows in the day is the shows, this is
#                          with the bag barrel and straight as he was a
#                          him, make on the starts the shows the
#
# ----- diversity: 1.0
# ----- Generating with seed: "                         What so you wan"
#                          What so you want maked and kill next bat, room, this fucking too?
#
#                APERDOMP yok it. The gists time
#                          if go dor, what is a lasaffage that I saush
#                          look ouching it.
#
#                                      STRETT Elling)
#                          Foray's goin' at Mongier soys ass gless
#                 mucotaraitl. And Marsellus sittin' what
#
# Epoch 25/50
# 7614/7614 [==============================] - 7s 915us/step - loss: 0.7005 - categorical_crossentropy: 0.7005 - accuracy: 0.8023
#
# ----- Generating text after Epoch: 24
# ----- diversity: 0.2
# ----- Generating with seed: "                    And, uh, how 'bout y"
#                     And, uh, how 'bout you get the restaurant. The
#                          from the big man, it's not here and the
#                          the regist heard to be cool. He
#                the bag for the table – we real who you get
#                          the expresses on the bathroom with the bag.
#                          What when you get the car and stard and
#                          the expresse in the b
# ----- diversity: 0.5
# ----- Generating with seed: "                    And, uh, how 'bout y"
#                     And, uh, how 'bout your Malibu blooking out a
#                          eat the grabbong a sees, what eyes and
#                          my fuckin' comes the mennesspy fired man
#                          eating the store of the little before on the
#                          you don't be give me a place most
#                          had the ring down into bedroom. The
#                          So you know when
# ----- diversity: 1.0
# ----- Generating with seed: "                    And, uh, how 'bout y"
#                     And, uh, how 'bout you're with ch.ne on the
#                face. The make a table. The honey alas.
#                          Foray fuckin' merorice, Vincent I watch up. Firpf.
#
#                                      BRETT
#                          In the regannizse. Get my in the
#                in fuck there's one if you the fingers frogh open. Dig a place, Vincent, in will be the
#                your dream, bo
# Epoch 26/50
# 7614/7614 [==============================] - 7s 909us/step - loss: 0.6965 - categorical_crossentropy: 0.6965 - accuracy: 0.8033
#
# ----- Generating text after Epoch: 25
# ----- diversity: 0.2
# ----- Generating with seed: "                        by the inequitie"
#                         by the inequities the shower out of a
#                          the show, the show restaurant this shit of a too a moment of a
#
# ----- diversity: 0.5
# ----- Generating with seed: "                        by the inequitie"
#                         by the inequities here you and the
#                          the show, but it's gonna be out where the
#                          that and wark.
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "                        by the inequitie"
#                         by the inequities.
#
#                                                        JULES
#                                           JODY
#                                 BACT
#                           He drinks, should be leather the
#                          moye up a JULES
#                          – lost opens in the tride.
#
#                                      (into eig)
#                                      if
# Epoch 27/50
# 7614/7614 [==============================] - 6s 780us/step - loss: 0.6923 - categorical_crossentropy: 0.6923 - accuracy: 0.8044 0s - loss: 0.6887 - categorical_crossentropy: 0.6887 - accuracy:
#
# ----- Generating text after Epoch: 26
# ----- diversity: 0.2
# ----- Generating with seed: " the Douglas Sirk steak.
#
#             "
#  the Douglas Sirk steak.
#
#
# ----- diversity: 0.5
# ----- Generating with seed: " the Douglas Sirk steak.
#
#             "
#  the Douglas Sirk steak.
#
#                                                                                              VINCENT
#                          It a prothers her hand-clear standfaches front of
#                          doesn't mean the bag.
#
#                                      VINCENT
#                          Not a take men. And the show
#                situation.
#
#
# ----- diversity: 1.0
# ----- Generating with seed: " the Douglas Sirk steak.
#
#             "
#  the Douglas Sirk steak.
#
#                                      "DITTENSELY VINCENT'S VOED / RITE / DITS) – MARNE."... betalition.
#
#                                      BUTCH
#                               (to Marvien "HIPS the should be and interso about
#                          overed up. She eat what and windor.
#
#                Fucker HAGE SHOO."!.!
#
#                The Wolf selisped reacces to gear I
#                apalibb
# Epoch 28/50
# 7614/7614 [==============================] - 6s 819us/step - loss: 0.6875 - categorical_crossentropy: 0.6875 - accuracy: 0.8052
#
# ----- Generating text after Epoch: 27
# ----- diversity: 0.2
# ----- Generating with seed: "ings. Both of
#                her ears "
# ings. Both of
# ...
#                          this tow?
#
#                Vincentborly Vincent)
#                              Low' do what you ever hapers.
#
#                Butch. An eonized, do it.
#
#                The Malibu wall
# Epoch 42/50
# 7614/7614 [==============================] - 7s 947us/step - loss: 0.6444 - categorical_crossentropy: 0.6444 - accuracy: 0.8165
#
# ----- Generating text after Epoch: 41
# ----- diversity: 0.2
# ----- Generating with seed: " a rag doll. She's twisted on her back. "
#  a rag doll. She's twisted on her back. You
#                          sign probablemy-hit's case.
#
#                                      BUTCH
#                          What's her as he was a situation of the
#                the case of that and a look about drinking in the front
#                          that and you started that and you a couple
#                          that and you started to his ass.
#
#
# ----- diversity: 0.5
# ----- Generating with seed: " a rag doll. She's twisted on her back. "
#  a rag doll. She's twisted on her back. You stausa have
#                          the back and stands on a lones, and he dead boy
#                          stay shit of the way some the street, not it
#                          better little hamming out of the closed.
#
#                                                                                JULES
#                          Now I'm gonna danna knows it'd the back. Your
#
# ----- diversity: 1.0
# ----- Generating with seed: " a rag doll. She's twisted on her back. "
#  a rag doll. She's twisted on her back. You're
#                          you still wead upco the broth that fucked himself do
#                          The Cluen his quitcosteretirg)
#                          One on the hash. It's reacking, Jules. Clming its dead into the moment
#                          that, bringo this pawnshop fame of charish reach
#                          my watch the place.
#
#
# Epoch 43/50
# 7614/7614 [==============================] - 7s 915us/step - loss: 0.6431 - categorical_crossentropy: 0.6431 - accuracy: 0.8172
#
# ----- Generating text after Epoch: 42
# ----- diversity: 0.2
# ----- Generating with seed: "police cars with their SIRENS BLARING ra"
# police cars with their SIRENS BLARING rasuble. The
#                          the only that and you wanna know what to
#                          the bag.
#
#                                      BUTCH
#                          What does to a big furger and start and sead and starts to
#                          the way the way the world on the fire! Sure
#                          and straight up on the shower door, the
#
# ----- diversity: 0.5
# ----- Generating with seed: "police cars with their SIRENS BLARING ra"
# police cars with their SIRENS BLARING radies and hands the thing in front of the Magartleation
#                          find it, by not head: "HIPS the street. The
#                          the only seen a guys out of a body studs it if
#                          ever hear good idea. Now I'll hands
#                          seems to himself.
#
#                                      BRETT
#                          Esearcle. What was a
# ----- diversity: 1.0
# ----- Generating with seed: "police cars with their SIRENS BLARING ra"
# police cars with their SIRENS BLARING races time to to Vincent, sings are: "yese)
#                          What I was seemies, let's go back to Jusimarry: Nove, with
#                shuffer from the Bunch, bod... sinds the streect. And
#                .
#                          Chevy sad grease pushing wrules.
#
#                                      VINCENT
#                          Fabienne cirst lexice Locky Novat RANS in
#
# Epoch 44/50
# 7614/7614 [==============================] - 7s 901us/step - loss: 0.6416 - categorical_crossentropy: 0.6416 - accuracy: 0.8180
#
# ----- Generating text after Epoch: 43
# ----- diversity: 0.2
# ----- Generating with seed: "                         I'm not a cobb "
#                          I'm not a cobb of no.
#
#                                      MAYNARD
#                          What was it?
#
#                                      JULES
#                          What does to the shot.
#
#                                      VINCENT
#                          I'm not don't was to get your ass in face,
#                          that and I wanna know what I was some
#                          th
# ----- diversity: 0.5
# ----- Generating with seed: "                         I'm not a cobb "
#                          I'm not a cobb of takes a sip of that
#                          on the Wolf shot. Her on the pauran.
#
#                                      JULES
#                          An any that and you give a table
#                          my hash, but it's gotta stand to sure the
#                          to goy maynare of the finders.
#
#                The Gimp-gots the pap of the will is to the
#
# ----- diversity: 1.0
# ----- Generating with seed: "                         I'm not a cobb "
#                          I'm not a cobb tabationaly pack around
#                us here?
#
#                                      MAYNARD
#                          Well about they styronets Morger?
#
#                Zed girl paces of the grinving on toutning
#                          good. So he Blead yearsall, FIETS him it. There ovallelowry parkin-
#                          fuckin' points anybody bit in thill him.
#
#
# Epoch 45/50
# 7614/7614 [==============================] - 7s 893us/step - loss: 0.6404 - categorical_crossentropy: 0.6404 - accuracy: 0.8186
#
# ----- Generating text after Epoch: 44
# ----- diversity: 0.2
# ----- Generating with seed: "             MARSELLUS
#                 "
#              MARSELLUS
#                          I don't know what the fuckin' thing the
#                          the shot.
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "             MARSELLUS
#                 "
#              MARSELLUS
#                          Goddamn they see shit they called to ence
#                          freaks the shot.
#
#                                                                                                                                       JULES
#                          I gotta give you.
#
#                                                                                                    JULES
#
# ----- diversity: 1.0
# ----- Generating with seed: "             MARSELLUS
#                 "
#              MARSELLUS
#                          Yes, beroning?
#
#                                      WIVIN
#                          Exel  Head)
#                          Hello! Aid them, puest, and SLAMS the
#                          find yours now, speckly.
#
#                She drivan?
#
#                                             MIA
#                               (over here pleasing his lomish remote riplifny sin's
#
# Epoch 46/50
# 7614/7614 [==============================] - 7s 888us/step - loss: 0.6379 - categorical_crossentropy: 0.6379 - accuracy: 0.8189
#
# ----- Generating text after Epoch: 45
# ----- diversity: 0.2
# ----- Generating with seed: "Lash Larue?  Can you
#                  "
# Lash Larue?  Can you
#                          they pierce to me and starts to the back on the
#                          they got a man our liquor stering it and the
#                the bag and to and they call a big started on the back.
#                          they got a bitch sermies the first to the bag and
#                          they call a good it from his back to the bag an the back of
#                          they cal
# ----- diversity: 0.5
# ----- Generating with seed: "Lash Larue?  Can you
#                  "
# Lash Larue?  Can you
#                          they see and dead as bald be called to knocking and the trunks, they'll
#                          you find you to a massead I onlous still
#                          they get up.
#
#                                      JULES
#                          What's no problems.
#
#                                      MARSELLUS
#                          It's a medarate in the bag for a teline.
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "Lash Larue?  Can you
#                  "
# Lash Larue?  Can you
#                          "The willwases his in a who'll
#                          thindond to and drie is a walled of the toullo's
#                        somethin'?
#
#                                      LANCE
#                          will guy betil place on-parine, not and chear reaches hurger aftack.
#
#                                      FABIENNE
#                          What?
#
#
# Epoch 47/50
# 7614/7614 [==============================] - 7s 896us/step - loss: 0.6369 - categorical_crossentropy: 0.6369 - accuracy: 0.8185
#
# ----- Generating text after Epoch: 46
# ----- diversity: 0.2
# ----- Generating with seed: "        us is Butch's French girlfriend,"
#         us is Butch's French girlfriend, which fing read and starts to the back off the door, strugger a
#                          that one, they seems and sloor.
#
#                                      FABIENNE
#                          I don't know what they seem like they're
#                          that and you step shoulda cal to car of a
#                          the way is a chare and starts to the shot.
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "        us is Butch's French girlfriend,"
#         us is Butch's French girlfriend, the same from the fuck out of the doorbeet and she coulda
#                          they should be fuckin' die. You steath
#                          they pot, I want to the one was because
#                          each other, man, I don't wanna be the
#                          they get a pretting what he want to the descriped to the light.
#
#                                      JULES
#
# ----- diversity: 1.0
# ----- Generating with seed: "        us is Butch's French girlfriend,"
#         us is Butch's French girlfriend, and Vincent quick a dut.
#
#                Bacro becie "Malosn lot of dibloows with Cocidy up.
#
#                                      YOUNG WOMAN
#                          Eomeroone.
#
#                                      BUTCH
#                               (over intere teens, I wouldn't
#                          startlingu in front of Marvin)
#
#                LIVY BOOMBB-TMENNG) – MORNING
#
# Epoch 48/50
# 7614/7614 [==============================] - 8s 1ms/step - loss: 0.6355 - categorical_crossentropy: 0.6355 - accuracy: 0.8196
#
# ----- Generating text after Epoch: 47
# ----- diversity: 0.2
# ----- Generating with seed: "               through that. So what you"
#                through that. So what you think I'm gonna
#                          they pulls to tell you think I'm not even
#                          that was that, you're gonna give your
#                          that was that that that what has the
#                              they poting, a tell reaches his head: "yes."
#
#                                      JULES
#                          I don't know what they call they poin
# ----- diversity: 0.5
# ----- Generating with seed: "               through that. So what you"
#                through that. So what you think I'm gonna
#                          let's never makes that mean thing to
#                          a big back to smaked of the two men.
#
#                Then when you were that was because his
#                          worken have to be a bunch in
#                          stick down to the carter that bed, see
#                          they walk they get it, little memes any of
#
# ----- diversity: 1.0
# ----- Generating with seed: "               through that. So what you"
#                through that. So what you're gonna have charity the said it
#                          days: "Nonne)
#                          I mean be all you, you're as you're
#                          out this?
#
#                Vincent and Mensters HRUTH POL STREEN, a real fat
#                          grunken't let's not yours friend, quicts
#                          would cammia. That's it. I way, behind her the
#
# Epoch 49/50
# 7614/7614 [==============================] - 7s 946us/step - loss: 0.6336 - categorical_crossentropy: 0.6336 - accuracy: 0.8203
#
# ----- Generating text after Epoch: 48
# ----- diversity: 0.2
# ----- Generating with seed: "                                    LANC"
#                                     LANCE
#                          What's her nom out of his pautha man does he
#                                      JULES
#                          What's her nom of the car to can like
#                          you didn't life to is and starts to
#                          a word of fuckin' with Cheese.
#
#                                      FABIENNE
#                          What's her name?
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "                                    LANC"
#                                     LANCE
#                          We're laugh out their she's seemies.
#
#                                        BUTCH
#                          I got a miracle fament.
#
#                                      VINCENT
#                          You do that and years.
#
#                                      BUTCH
#                          Okay problem?
#
#                                      FABIENNE
#
# ----- diversity: 1.0
# ----- Generating with seed: "                                    LANC"
#                                     LANCE
#                          Unvor does are go.
#
#                                      BUTCH
#                          You want maily Sary.
#
#                                      JALES
#                          dead contlical STECES JiGET (ROSSIN SHAP – MORNING
#
#                The stoul packin'! I'm heare sompthing before in
#                take a pit give you that as hag's but
#
# Epoch 50/50
# 7614/7614 [==============================] - 6s 785us/step - loss: 0.6326 - categorical_crossentropy: 0.6326 - accuracy: 0.8203
#
# ----- Generating text after Epoch: 49
# ----- diversity: 0.2
# ----- Generating with seed: "f the
#                bathroom, tighten"
# f the
#                bathroom, tightena you want to back of
#                          to be the really massage.
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "f the
#                bathroom, tighten"
# f the
#                bathroom, tightening encemp him with the word.
#
#                                        BUTCH
#                          Well, I don't know what I've been torce
#                          world you were should be fuckin' way. I
#                          to gonna say, with the back of you
#                          all you take the one.
#
#                                        BUTCH
#                          Whop
# ----- diversity: 1.0
# ----- Generating with seed: "f the
#                bathroom, tighten"
# f the
#                bathroom, tightens laugh)
#                          Wold appropeugar ine, bany?
#
#                                        FIV'E'S MONCONA
#                          Yes.
#
#                                      JULES
#                          Ollimener.
#
#                FADE hOLL WILVY
#                               And in the fingers to tikes.
#
#                Fack and killelft." Butch dain.
#
#                Mia

# %% [markdown]
# > **Ex. 5.1.2**: Add a callback for Tensorboard, so you can log the training process. Start training the network (takes ~10 minutes on my computer). While it's running move on to the next question.

# %%
# %tensorboard --logdir logs/wk5_1
# Out:
#       <iframe id="tensorboard-frame-6d7564eb0b217663" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-6d7564eb0b217663");
#           const url = new URL("/", window.location);
#           url.port = 6006;
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# > **Ex. 5.1.3**: Answer the questions in the code above (look for code comments starting with `Q:`).

# %% [markdown]
# > **Ex. 5.1.4**: Did the network finish training? Consider the generated text across epochs.
# 1. In the early batches (0-10), the generated text looks very bad. Can you explain why the low diversity generated text contains almost only the symbol " " (that is, spaces)?
# 2. The high diversity generated text is messed up too, but in a different way. Explain how.
# 3. In later batches (20-30) what do you notice is off about the low diversity generated text?
#
# 1. Early batches have low diversity and a lot of " " characters because the empty character is the most common one to appear in the text sequence, therefore the neural network easily predicts it as the most likely output after most characters.
# 2. The higher diversity text has more variation of characters, but they don't necessarily form coherent sentences
# 3. The low diversity text in the higher epochs still have a lot of empty space characters, but they also tend to have very common sentence structure (like repeating same words or similar spelled words).

# %% [markdown]
# > **Ex. 5.1.5**: For the network trained over all 50 epochs, generate a longer piece of text
# (say 5000 symbols long). Use the sentence `text[1486:1526]` as seed (starts with 'YOUNG MAN' ends with 'No, ')
# and set diversity to 0.5.
# Describe what features of the screenplay and language in general that the network learned in only 50 epochs.
# Also describe what serious mistakes it makes.

# %%
start_index = 1486
seqlen = 40
diversity = 0.5

generated = ''
sentence = text[start_index: start_index + seqlen]
generated += sentence
print('----- Generating with seed: "' + sentence + '"')
sys.stdout.write(generated)

for i in range(400):
    x_pred = np.zeros((1, seqlen, len(chars)))
    for t, char in enumerate(sentence):
        x_pred[0, t, char_indices[char]] = 1.

    # What is the dimensionality of `preds`? Why do we input `preds[0, -1]` to the `sample` function?
    preds = model.predict(x_pred, verbose=0)
    next_index = sample(preds[0, -1], diversity)
    next_char = indices_char[next_index]

    sentence = sentence[1:] + next_char

    sys.stdout.write(next_char)
    sys.stdout.flush()
print()
# Out:
# ----- Generating with seed: "YOUNG MAN
#                          No, "
# YOUNG MAN
#                          No, it's a fact on the toor to it what I
#                                      JULES
#                          Well, if it with this tomaticn.
#
#                                        VINCENT
#                          And withouster mind money on his as in
#                          to be they're a man, while I was to
#                          still can toward Vincent's prises the bathroom soulda

# %% [markdown]
# > **Ex. 5.1.6**: Do the same as above, but for 40 random letters (e.g. smash away on your keyboard) as seed. What happens? Can you explain why?

# %%
start_index = 0
seqlen = 40
diversity = 0.5

random_text = 'asdnkjsanglkseaklgj asjdbmnsavd hjgs eyfgashbdvnsdabkyasgb nbsdh bajsbcmnsdbgaksbfuidfhvuiasehf rsdgzsdvbj hfvhB Khv kzsdb,ds'

generated = ''
sentence = random_text[start_index: start_index + seqlen]
generated += sentence
print('----- Generating with seed: "' + sentence + '"')
sys.stdout.write(generated)

for i in range(400):
    x_pred = np.zeros((1, seqlen, len(chars)))
    for t, char in enumerate(sentence):
        x_pred[0, t, char_indices[char]] = 1.

    # What is the dimensionality of `preds`? Why do we input `preds[0, -1]` to the `sample` function?
    preds = model.predict(x_pred, verbose=0)
    next_index = sample(preds[0, -1], diversity)
    next_char = indices_char[next_index]

    sentence = sentence[1:] + next_char

    sys.stdout.write(next_char)
    sys.stdout.flush()
print()
# Out:
# ----- Generating with seed: "asdnkjsanglkseaklgj asjdbmnsavd hjgs eyf"
# asdnkjsanglkseaklgj asjdbmnsavd hjgs eyfing the
#                          and toward the wall.
#
#                                        VINCENT
#                                      FABIENNE
#                          I don't mean I have a fuckin' gotto
#                          fuck does a smoke.
#
#                                                                                     JULES
#                          Yeah, in the front o

# %% [markdown]
# > **Challenge** Download [this](https://www.yelp.com/dataset/download) Yelp dataset and train a model that predicts rating given a review text!
